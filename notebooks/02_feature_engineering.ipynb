# %%
import os
import pandas as pd
import numpy as np

# %%
PROCESSED_DIR = "../data/processed"
INPUT_CSV = os.path.join(PROCESSED_DIR, "corridor_shipments_clean.csv")

# %%
# Outputs from this notebook
FEATURES_CSV = os.path.join(PROCESSED_DIR, "corridor_features.csv")
FEATURES_PARQUET = os.path.join(PROCESSED_DIR, "corridor_features.parquet")

os.makedirs(PROCESSED_DIR, exist_ok=True)

# %% [markdown]
# #### Load Cleaned Data

# %%
# -----------------------------
# Load the cleaned dataset (Notebook 01 output)
# -----------------------------
date_cols = ["depart_time", "border_arrival_time", "border_exit_time", "arrival_time"]

df = pd.read_csv(INPUT_CSV, parse_dates=date_cols)

print("Loaded:", df.shape)
df.head()
# Out:
# Loaded: (1000, 19)
#   shipment_id truck_id origin_port  border destination         depart_time  \
# 0    SHP00001   TRK754     Mombasa  Malaba     Kampala 2024-01-29 00:00:00
# 1    SHP00002   TRK704     Mombasa  Malaba     Kampala 2024-04-18 01:00:00
# 2    SHP00003   TRK325     Mombasa  Malaba     Kampala 2024-04-24 18:00:00
# 3    SHP00004   TRK320     Mombasa  Malaba     Kampala 2024-03-27 03:00:00
# 4    SHP00005   TRK649     Mombasa  Malaba     Kampala 2024-02-01 12:00:00
#
#          border_arrival_time           border_exit_time  \
# 0 2024-01-29 12:26:57.490795 2024-01-29 19:37:49.228206
# 1 2024-04-18 09:10:43.619940 2024-04-18 13:39:43.839026
# 2 2024-04-25 03:40:08.919298 2024-04-25 07:48:57.582009
# 3 2024-03-27 11:33:23.310217 2024-03-27 15:42:12.174996
# 4 2024-02-01 20:28:22.084278 2024-02-02 10:25:18.999930
#
#                 arrival_time          goods_category  weight_kg  \
# 0 2024-01-30 00:36:35.670901             Electronics   16047.07
# 1 2024-04-18 18:32:12.225863  Construction Materials   27040.37
# 2 2024-04-25 15:17:35.506628                Textiles   10252.37
# 3 2024-03-27 20:05:24.890822                Textiles    6095.60
# 4 2024-02-02 15:35:40.767182         Pharmaceuticals    5711.12
#
#    declared_value_usd  fuel_price_usd_per_litre  rainfall_indicator  \
# 0            20438.99                      1.55                   0
# 1            32255.69                      1.46                   1
# 2            13212.20                      1.27                   0
# 3             6005.17                      1.12                   1
# 4             8013.81                      1.39                   0
#
#          delay_reason  travel_to_border_hours  clearance_hours  \
# 0                 NaN               12.449303         7.181038
# 1                 NaN                8.178783         4.483394
# 2                 NaN                9.669144         4.146851
# 3                 NaN                8.556475         4.146907
# 4  Customs Inspection                8.472801        13.949143
#
#    travel_to_destination_hours  total_transit_hours
# 0                     4.979567            24.609909
# 1                     4.874552            17.536729
# 2                     7.477201            21.293196
# 3                     4.386866            17.090247
# 4                     5.172713            27.594658

# %% [markdown]
# #### Core Time Features

# %%
# -----------------------------
# Core duration features (hours)
# -----------------------------
# These are the main operational metrics for corridor efficiency.
df["travel_to_border_hours"] = (
    df["border_arrival_time"] - df["depart_time"]
).dt.total_seconds() / 3600

df["clearance_hours"] = (
    df["border_exit_time"] - df["border_arrival_time"]
).dt.total_seconds() / 3600

df["travel_to_destination_hours"] = (
    df["arrival_time"] - df["border_exit_time"]
).dt.total_seconds() / 3600

df["total_transit_hours"] = (
    df["arrival_time"] - df["depart_time"]
).dt.total_seconds() / 3600

# Delay label (binary) for classification tasks
df["is_delayed"] = (df["clearance_hours"] > 12).astype(int)

df[["shipment_id", "travel_to_border_hours", "clearance_hours", "total_transit_hours", "is_delayed"]].head()
# Out:
#   shipment_id  travel_to_border_hours  clearance_hours  total_transit_hours  \
# 0    SHP00001               12.449303         7.181038            24.609909
# 1    SHP00002                8.178783         4.483394            17.536729
# 2    SHP00003                9.669144         4.146851            21.293196
# 3    SHP00004                8.556475         4.146907            17.090247
# 4    SHP00005                8.472801        13.949143            27.594658
#
#    is_delayed
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1

# %% [markdown]
# #### Calendar & Seasonality Features

# %%
# -----------------------------
# Calendar features for patterns + seasonality
# -----------------------------
df["depart_date"] = df["depart_time"].dt.date
df["depart_year"] = df["depart_time"].dt.year
df["depart_month"] = df["depart_time"].dt.month
df["depart_day"] = df["depart_time"].dt.day

# Day-of-week features
df["depart_day_of_week_num"] = df["depart_time"].dt.dayofweek  # Monday=0 ... Sunday=6
df["depart_day_name"] = df["depart_time"].dt.day_name()

# Hour-of-day features (useful if congestion depends on time)
df["depart_hour"] = df["depart_time"].dt.hour

# Weekend flag
df["is_weekend"] = df["depart_day_of_week_num"].isin([5, 6]).astype(int)

df[["shipment_id", "depart_time", "depart_day_name", "depart_hour", "is_weekend"]].head()
# Out:
#   shipment_id         depart_time depart_day_name  depart_hour  is_weekend
# 0    SHP00001 2024-01-29 00:00:00          Monday            0           0
# 1    SHP00002 2024-04-18 01:00:00        Thursday            1           0
# 2    SHP00003 2024-04-24 18:00:00       Wednesday           18           0
# 3    SHP00004 2024-03-27 03:00:00       Wednesday            3           0
# 4    SHP00005 2024-02-01 12:00:00        Thursday           12           0

# %% [markdown]
# #### Operational Flags (Bottlenecks & Business Logic)

# %%
# -----------------------------
# Operational flags: help segmentation and storytelling
# -----------------------------

# "Long clearance" buckets (makes dashboards cleaner)
# You can tune these thresholds based on what you want to communicate.
df["clearance_bucket"] = pd.cut(
    df["clearance_hours"],
    bins=[-0.01, 2, 6, 12, 24, np.inf],
    labels=["0–2h", "2–6h", "6–12h", "12–24h", "24h+"]
)

# "Long transit" bucket
df["transit_bucket"] = pd.cut(
    df["total_transit_hours"],
    bins=[-0.01, 12, 18, 24, 36, np.inf],
    labels=["0–12h", "12–18h", "18–24h", "24–36h", "36h+"]
)

# High value shipment flag (top 10% declared value)
p90_value = df["declared_value_usd"].quantile(0.90)
df["is_high_value"] = (df["declared_value_usd"] >= p90_value).astype(int)

# Heavy shipment flag (top 10% weight)
p90_weight = df["weight_kg"].quantile(0.90)
df["is_heavy"] = (df["weight_kg"] >= p90_weight).astype(int)

df[["shipment_id", "clearance_bucket", "transit_bucket", "is_high_value", "is_heavy"]].head()
# Out:
#   shipment_id clearance_bucket transit_bucket  is_high_value  is_heavy
# 0    SHP00001            6–12h         24–36h              0         0
# 1    SHP00002             2–6h         12–18h              0         0
# 2    SHP00003             2–6h         18–24h              0         0
# 3    SHP00004             2–6h         12–18h              0         0
# 4    SHP00005           12–24h         24–36h              0         0

# %% [markdown]
# #### Rolling & Trend Features (Time-Aware)

# %%
# -----------------------------
# Time-aware rolling metrics
# -----------------------------
# Sort by depart_time to compute rolling features correctly.
df = df.sort_values("depart_time").reset_index(drop=True)

# Rolling averages for corridor congestion signals
# (window=30 means last 30 shipments; you can also do daily rolling later)
df["rolling_clearance_mean_30"] = df["clearance_hours"].rolling(window=30, min_periods=10).mean()
df["rolling_delay_rate_30"] = df["is_delayed"].rolling(window=30, min_periods=10).mean()

# Rolling median is robust to outliers
df["rolling_clearance_median_30"] = df["clearance_hours"].rolling(window=30, min_periods=10).median()

df[["depart_time", "clearance_hours", "rolling_clearance_mean_30", "rolling_delay_rate_30"]].head(15)
# Out:
#            depart_time  clearance_hours  rolling_clearance_mean_30  \
# 0  2024-01-01 03:00:00         8.522000                        NaN
# 1  2024-01-01 12:00:00         4.780147                        NaN
# 2  2024-01-01 16:00:00        20.000000                        NaN
# 3  2024-01-01 19:00:00        11.657312                        NaN
# 4  2024-01-02 00:00:00        12.444743                        NaN
# 5  2024-01-02 08:00:00         9.863236                        NaN
# 6  2024-01-02 16:00:00         9.585429                        NaN
# 7  2024-01-02 17:00:00        17.981120                        NaN
# 8  2024-01-02 22:00:00        10.365941                        NaN
# 9  2024-01-03 02:00:00         7.084482                  11.228441
# 10 2024-01-03 02:00:00         5.800397                  10.734982
# 11 2024-01-03 03:00:00        10.984891                  10.755808
# 12 2024-01-03 06:00:00         5.461520                  10.348555
# 13 2024-01-03 08:00:00         2.086544                   9.758412
# 14 2024-01-03 14:00:00         4.108560                   9.381755
#
#     rolling_delay_rate_30
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                0.300000
# 10               0.272727
# 11               0.250000
# 12               0.230769
# 13               0.214286
# 14               0.200000

# %% [markdown]
# #### Encode Delay Reason (Analytics-Friendly)

# %%
# -----------------------------
# Normalize delay_reason into groups (optional)
# -----------------------------
# This helps dashboards and modeling (fewer unique categories).
reason_map = {
    "None": "None",
    "Customs Inspection": "Border/Customs",
    "Documentation Issues": "Border/Customs",
    "System Downtime": "Border Systems",
    "Traffic Congestion": "Road/Traffic",
    "Weather Disruption": "Weather",
    "Truck Breakdown": "Vehicle/Mechanical"
}

df["delay_reason_group"] = df["delay_reason"].map(reason_map).fillna("Other")

df[["delay_reason", "delay_reason_group"]].value_counts().head(10)
# Out:
# delay_reason          delay_reason_group
# Customs Inspection    Border/Customs        23
# Weather Disruption    Weather               20
# Truck Breakdown       Vehicle/Mechanical    20
# Traffic Congestion    Road/Traffic          19
# Documentation Issues  Border/Customs        13
# System Downtime       Border Systems        12
# Name: count, dtype: int64

# %% [markdown]
# #### Cost Features (for impact analysis)

# %%
# -----------------------------
# Cost-of-delay simulation feature (for dashboards + reports)
# -----------------------------
# Use a simple assumption; you can parameterize it later.
COST_PER_HOUR_USD = 150

# Only charge cost when delayed (clearance > 12 hours)
df["delay_cost_usd"] = np.where(
    df["is_delayed"] == 1,
    df["clearance_hours"] * COST_PER_HOUR_USD,
    0
)

df[["shipment_id", "clearance_hours", "is_delayed", "delay_cost_usd"]].head()
# Out:
#   shipment_id  clearance_hours  is_delayed  delay_cost_usd
# 0    SHP00823         8.522000           0        0.000000
# 1    SHP00640         4.780147           0        0.000000
# 2    SHP00639        20.000000           1     3000.000000
# 3    SHP00842        11.657312           0        0.000000
# 4    SHP00652        12.444743           1     1866.711417

# %% [markdown]
# #### ANALYTICS-READY TABLE (for EDA + BI)

# %%
# -----------------------------
# 1) ANALYTICS-READY TABLE (for EDA + BI)
# -----------------------------
# Keep timestamps + categories + flags for slicing and time trends
analytics_cols = [
    # Identifiers
    "shipment_id", "truck_id",

    # Corridor reference (good for storytelling)
    "origin_port", "border", "destination",

    # ✅ Timestamps (critical for real time trends)
    "depart_time", "border_arrival_time", "border_exit_time", "arrival_time",

    # Categories for slicing
    "goods_category", "delay_reason", "delay_reason_group",

    # Core numeric fields
    "weight_kg", "declared_value_usd", "fuel_price_usd_per_litre", "rainfall_indicator",

    # Engineered operational metrics
    "travel_to_border_hours", "clearance_hours", "travel_to_destination_hours", "total_transit_hours",

    # Time features
    "depart_year", "depart_month", "depart_day", "depart_day_name",
    "depart_day_of_week_num", "depart_hour", "is_weekend",

    # Flags + buckets
    "is_high_value", "is_heavy", "clearance_bucket", "transit_bucket",

    # Rolling congestion signals
    "rolling_clearance_mean_30", "rolling_clearance_median_30", "rolling_delay_rate_30",

    # Cost simulation + target
    "delay_cost_usd", "is_delayed"
]

analytics_df = df[analytics_cols].copy()

print("analytics_df shape:", analytics_df.shape)
analytics_df.head()
# Out:
# analytics_df shape: (1000, 36)
#   shipment_id truck_id origin_port  border destination         depart_time  \
# 0    SHP00823   TRK600     Mombasa  Malaba     Kampala 2024-01-01 03:00:00
# 1    SHP00640   TRK331     Mombasa  Malaba     Kampala 2024-01-01 12:00:00
# 2    SHP00639   TRK688     Mombasa  Malaba     Kampala 2024-01-01 16:00:00
# 3    SHP00842   TRK761     Mombasa  Malaba     Kampala 2024-01-01 19:00:00
# 4    SHP00652   TRK182     Mombasa  Malaba     Kampala 2024-01-02 00:00:00
#
#          border_arrival_time           border_exit_time  \
# 0 2024-01-01 14:17:06.805672 2024-01-01 22:48:26.005174
# 1 2024-01-02 01:43:29.755472 2024-01-02 06:30:18.284027
# 2 2024-01-02 04:14:44.282085 2024-01-03 00:14:44.282085
# 3 2024-01-02 05:51:33.025321 2024-01-02 17:30:59.349309
# 4 2024-01-02 09:04:35.317693 2024-01-02 21:31:16.391695
#
#                 arrival_time   goods_category  ... is_weekend is_high_value  \
# 0 2024-01-02 03:04:38.934531             Fuel  ...          0             0
# 1 2024-01-02 13:46:37.147922        Machinery  ...          0             0
# 2 2024-01-03 07:19:46.547138        Machinery  ...          0             0
# 3 2024-01-03 01:07:20.157222  Pharmaceuticals  ...          0             0
# 4 2024-01-03 01:52:40.025551  Pharmaceuticals  ...          0             0
#
#    is_heavy  clearance_bucket  transit_bucket  rolling_clearance_mean_30  \
# 0         0             6–12h          24–36h                        NaN
# 1         0              2–6h          24–36h                        NaN
# 2         0            12–24h            36h+                        NaN
# 3         0             6–12h          24–36h                        NaN
# 4         0            12–24h          24–36h                        NaN
#
#    rolling_clearance_median_30  rolling_delay_rate_30  delay_cost_usd  \
# 0                          NaN                    NaN        0.000000
# 1                          NaN                    NaN        0.000000
# 2                          NaN                    NaN     3000.000000
# 3                          NaN                    NaN        0.000000
# 4                          NaN                    NaN     1866.711417
#
#    is_delayed
# 0           0
# 1           0
# 2           1
# 3           0
# 4           1
#
# [5 rows x 36 columns]

# %% [markdown]
# #### MODEL-READY TABLE (for ML)

# %%
# -----------------------------
# 2) MODEL-READY TABLE (for ML)
# -----------------------------
# Remove columns that can cause leakage or are not available at prediction time.
# NOTE: We should NOT include 'clearance_hours' if we're predicting delays BEFORE clearance happens.
# We'll keep two versions:
#   - model_df_post (post-event, for understanding)
#   - model_df_pre  (pre-event, for real predictive use)

# A) Post-event modeling dataset (OK for learning, but not real-time predictive)
model_cols_post = [
    "shipment_id", "truck_id",
    "depart_time",
    "goods_category", "delay_reason_group",
    "weight_kg", "declared_value_usd", "fuel_price_usd_per_litre", "rainfall_indicator",
    "travel_to_border_hours",
    "depart_month", "depart_day_of_week_num", "depart_hour", "is_weekend",
    "is_high_value", "is_heavy",
    "rolling_clearance_mean_30", "rolling_clearance_median_30", "rolling_delay_rate_30",
    "is_delayed"
]
model_df_post = df[model_cols_post].copy()

# B) Pre-event modeling dataset (best practice: only features known BEFORE border clearance)
# Here we exclude clearance_hours and delay_reason (because you only know them after delay happens).
model_cols_pre = [
    "shipment_id", "truck_id",
    "depart_time",
    "goods_category",
    "weight_kg", "declared_value_usd", "fuel_price_usd_per_litre", "rainfall_indicator",
    "depart_month", "depart_day_of_week_num", "depart_hour", "is_weekend",
    "is_high_value", "is_heavy",
    "rolling_delay_rate_30",  # historical congestion signal
    "is_delayed"
]
model_df_pre = df[model_cols_pre].copy()

print("model_df_post shape:", model_df_post.shape)
print("model_df_pre  shape:", model_df_pre.shape)
# Out:
# model_df_post shape: (1000, 20)
# model_df_pre  shape: (1000, 16)

# %% [markdown]
# #### Save Dataset

# %%
# -----------------------------
# Save outputs
# -----------------------------
PROCESSED_DIR = "../data/processed"
os.makedirs(PROCESSED_DIR, exist_ok=True)

analytics_path_csv = os.path.join(PROCESSED_DIR, "corridor_analytics.csv")
analytics_path_parquet = os.path.join(PROCESSED_DIR, "corridor_analytics.parquet")

model_post_csv = os.path.join(PROCESSED_DIR, "corridor_model_post.csv")
model_pre_csv  = os.path.join(PROCESSED_DIR, "corridor_model_pre.csv")

analytics_df.to_csv(analytics_path_csv, index=False)
analytics_df.to_parquet(analytics_path_parquet, index=False)

model_df_post.to_csv(model_post_csv, index=False)
model_df_pre.to_csv(model_pre_csv, index=False)

print("Saved:")
print(" -", analytics_path_csv)
print(" -", analytics_path_parquet)
print(" -", model_post_csv)
print(" -", model_pre_csv)
# Out:
# Saved:
#  - ../data/processed\corridor_analytics.csv
#  - ../data/processed\corridor_analytics.parquet
#  - ../data/processed\corridor_model_post.csv
#  - ../data/processed\corridor_model_pre.csv
